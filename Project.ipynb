# %% [markdown]
# <a href="https://colab.research.google.com/github/Venk-88/Machine-Learning-Assignment/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Classification of Breast Cancer Classification Using Patient’s Clinical Data**

# %% [markdown]
# # **Data files loading**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Defining base features and measurement types as per wdbc.names
base_features = ['radius', 'texture', 'perimeter', 'area', 'smoothness',
                 'compactness', 'concavity', 'concave_points', 'symmetry', 'fractal_dimension']
measurement_types = ['mean', 'se', 'worst']

# Constructing the full column list
columns = ['ID', 'Diagnosis']
for m_type in measurement_types:
    for feature in base_features:
        columns.append(f"{feature}_{m_type}")

# Loading the dataset
df = pd.read_csv('wdbc.data', header=None, names=columns)
df.head()
# Out:
#          ID Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# #**EDA**

# %% [markdown]
# ## **Initial data inspection**

# %%
# General information about the dataset
print("Dataset Info:")
print(df.info())

# Summary statistics for numerical columns
print("\nStatistical Summary:")
display(df.describe())

# Checking for missing values
print("\nMissing Values:")
print(df.isnull().sum().sum())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       569 non-null    int64
#  1   Diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave_points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
# ...

# %% [markdown]
# ## **Target variable distribution**

# %%
# Visualizing the count of Malignant vs Benign cases
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Diagnosis', palette='viridis')
plt.title('Distribution of Diagnosis (M = Malignant, B = Benign)')
plt.show()

# Percentage distribution
print(df['Diagnosis'].value_counts(normalize=True) * 100)
# Out:
# /tmp/ipython-input-806405647.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Diagnosis', palette='viridis')
# Diagnosis
# B    62.741652
# M    37.258348
# Name: proportion, dtype: float64

# %% [markdown]
# ## **Numerical feature distribution**

# %%
# Boxplot for Mean features grouped by Diagnosis
mean_cols = [col for col in df.columns if '_mean' in col]

plt.figure(figsize=(15, 10))
for i, col in enumerate(mean_cols[0:6]): # Plotting first 6 for readability
    plt.subplot(2, 3, i + 1)
    sns.boxplot(data=df, x='Diagnosis', y=col, palette='Set2')
    plt.title(f'Distribution of {col}')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-4004221037.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Diagnosis', y=col, palette='Set2')
# /tmp/ipython-input-4004221037.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Diagnosis', y=col, palette='Set2')
# /tmp/ipython-input-4004221037.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Diagnosis', y=col, palette='Set2')
# /tmp/ipython-input-4004221037.py:7: FutureWarning:
#
# ...

# %% [markdown]
# ## **Correlation analysis**

# %%
# Computing correlation matrix for Mean features
corr_matrix = df[mean_cols].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap (Mean Features)')
plt.show()

# %% [markdown]
# ## **Multivariate scatter analysis**

# %%
# Scatter plot between Mean Radius and Mean Texture
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='radius_mean', y='texture_mean', hue='Diagnosis', alpha=0.7)
plt.title('Mean Radius vs. Mean Texture by Diagnosis')
plt.show()

# Pairplot for a subset of features
sns.pairplot(df[['Diagnosis', 'radius_mean', 'texture_mean', 'area_mean', 'smoothness_mean']],
             hue='Diagnosis', palette='husl')
plt.show()
